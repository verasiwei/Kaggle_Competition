# %%
distplot_log = sns.distplot(train["LogSalePrice"])
#do the standardization for the numeric variables in the total data set
standardize_features=total.loc[:,["LotFrontage","LotArea","MasVnrArea","BsmtFinSF1","BsmtFinSF2","BsmtUnfSF","TotalBsmtSF","1stFlrSF","2ndFlrSF","GrLivArea","GarageArea","WoodDeckSF","OpenPorchSF","EnclosedPorch","3SsnPorch","ScreenPorch","PoolArea"]]
standardize_features_values=(standardize_features-standardize_features.mean())/standardize_features.std()
pairplot=sns.pairplot(standardize_features_values)

total["WoodDeckSF"]
# Out:
# train  0         0
#        1       298
#        2         0
#        3         0
#        4       192
#        5        40
#        6       255
#        7       235
#        8        90
#        9         0
#        10        0
#        11      147
#        12      140
#        13      160
#        14        0
#        15       48
#        16        0
#        17        0
#        18        0
#        19        0
#        20      240
#        21        0
#        22      171
#        23      100
#        24      406
#        25        0
#        26      222
#        27        0
#        28      288
#        29       49
#               ...
# test   1429    184
#        1430      0
#        1431      0
#        1432      0
#        1433      0
#        1434    123
#        1435    128
#        1436    136
#        1437      0
#        1438    120
#        1439      0
#        1440      0
#        1441      0
#        1442    172
#        1443    161
#        1444      0
#        1445      0
#        1446    141
#        1447      0
#        1448      0
#        1449      0
#        1450      0
#        1451    160
#        1452      0
#        1453      0
#        1454      0
#        1455      0
#        1456    474
#        1457     80
#        1458    190
# Name: WoodDeckSF, Length: 2919, dtype: int64
